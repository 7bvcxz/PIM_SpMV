# %%
import torch
import torchvision.models as models
import numpy as np
import cvxpy as cp
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nnz_model = np.load('nnz_deepspeech2_0.9.npy')
plt.plot(nnz_model)
plt.show()
nnz_model = np.load('nnz_deepspeech2_0.8.npy')
plt.plot(nnz_model)
plt.show()
nnz_model = np.load('nnz_deepspeech2_0.7.npy')
plt.plot(nnz_model)
plt.show()
nnz_model = np.load('nnz_deepspeech2_0.6.npy')
plt.plot(nnz_model)
plt.show()

# %%
from scipy import interpolate
a = np.sort(fk_k, axis=1)
a = a[:, ::-1]
print(a)

for i in range(a.shape[0]):
    plt.plot(a[i])
plt.show()
# Out:
# [[12. 11. 10. ...  0.  0.  0.]
#  [15. 13. 11. ...  0.  0.  0.]
#  [10.  9.  9. ...  0.  0.  0.]
#  ...
#  [10.  9.  8. ...  0.  0.  0.]
#  [23. 18. 12. ...  0.  0.  0.]
#  [20. 15. 13. ...  0.  0.  0.]]

# %%
a = np.sort(dns_k, axis=1)
a = a[:, ::-1]
print(a)

for i in range(a.shape[0]):
    plt.plot(a[i])
all_k = np.sort(all_k)[::-1]
plt.plot(all_k)
plt.show()

# %%
from scipy import interpolate
a = np.sort(dns_k, axis=1)
a = a[:, ::-1]
print(a)

for i in range(a.shape[0]):
    ii = [j for j in range(2048)]
    x_new = np.linspace(0, 2048, 15)
    power_smooth = interpolate.make_interp_spline(ii, a[i])
    y_new = power_smooth(x_new)
    plt.plot(x_new, y_new)
all_k = np.sort(all_k)[::-1]
plt.plot(all_k)
plt.show()
# Out:
# [[0.45714286 0.40000001 0.40000001 ... 0.         0.         0.        ]
#  [0.5        0.5        0.5        ... 0.         0.         0.        ]
#  [0.77419353 0.58064514 0.58064514 ... 0.         0.         0.        ]
#  ...
#  [0.41176471 0.35294119 0.35294119 ... 0.         0.         0.        ]
#  [0.4848485  0.42424244 0.39393941 ... 0.         0.         0.        ]
#  [0.59375    0.5625     0.53125    ... 0.         0.         0.        ]]
